# %%
# Project - Momentum Stock Price Prediction
# Lenin Kamma
# 11/4/2020

# %%
# Import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
from matplotlib import colors
from matplotlib.ticker import PercentFormatter

# %%
# Import Tesla/Shop and Amazon data into a dataframe
tesla_df = pd.read_csv("C:/Lenin Data Science/Final Class/Final Class/Final Project/TSLA.csv")
shop_df = pd.read_csv("C:/Lenin Data Science/Final Class/Final Class/Final Project/SHOP.csv")
amazon_df = pd.read_csv("C:/Lenin Data Science/Final Class/Final Class/Final Project/AMZN.csv")

# %%
# View tesla data
tesla_df
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2010-06-29    3.800000    5.000000    3.508000    4.778000    4.778000
# 1     2010-06-30    5.158000    6.084000    4.660000    4.766000    4.766000
# 2     2010-07-01    5.000000    5.184000    4.054000    4.392000    4.392000
# 3     2010-07-02    4.600000    4.620000    3.742000    3.840000    3.840000
# 4     2010-07-06    4.000000    4.000000    3.166000    3.222000    3.222000
# ...          ...         ...         ...         ...         ...         ...
# 2600  2020-10-26  411.630005  425.760010  410.000000  420.279999  420.279999
# 2601  2020-10-27  423.760010  430.500000  420.100006  424.679993  424.679993
# 2602  2020-10-28  416.480011  418.600006  406.000000  406.019989  406.019989
# 2603  2020-10-29  409.959991  418.059998  406.459991  410.829987  410.829987
# 2604  2020-10-30  406.899994  407.589996  379.109985  388.040009  388.040009
#
#         Volume
# 0     93831500
# ...

# %%
# Find duplicate tesla data 
print(tesla_df.duplicated().sum())
# Find duplicate shop data
print(shop_df.duplicated().sum())
# Find duplicate amazon data
print(amazon_df.duplicated().sum())
# Out:
# 0
# 0
# 0

# %%
# Find NA data in tesla dataset
tesla_df.notna().sum()
# Out:
# Date         2605
# Open         2605
# High         2605
# Low          2605
# Close        2605
# Adj Close    2605
# Volume       2605
# dtype: int64

# %%
# Find NA data in shop dataset
shop_df.notna().sum()
# Out:
# Date         1259
# Open         1259
# High         1259
# Low          1259
# Close        1259
# Adj Close    1259
# Volume       1259
# dtype: int64

# %%
# Find NA data in Amazon dataset
amazon_df.notna().sum()
# Out:
# Date         2223
# Open         2223
# High         2223
# Low          2223
# Close        2223
# Adj Close    2223
# Volume       2223
# dtype: int64

# %%
# No duplicate data found in all 3 datasets
# No NA data found in all 3 datasets

# %%
# Work on each individual datasets

# %%
# Find the difference between high, low and open prices for tesla 
tesla_df["Diff_High_Low"] = tesla_df["High"]  - tesla_df["Low"]
tesla_df["Diff_High_Open"] = tesla_df["High"]  - tesla_df["Open"]
tesla_df["Diff_Open_Close"] = tesla_df["Open"]  - tesla_df["Close"]
tesla_df["Diff_Open_Low"] = tesla_df["Open"]  - tesla_df["Low"]

# %%
# Find the difference between high, low and open prices for Amazon 
amazon_df["Diff_High_Low"] = amazon_df["High"]  - amazon_df["Low"]
amazon_df["Diff_High_Open"] = amazon_df["High"]  - amazon_df["Open"]
amazon_df["Diff_Open_Close"] = amazon_df["Open"]  - amazon_df["Close"]
amazon_df["Diff_Open_Low"] = amazon_df["Open"]  - amazon_df["Low"]

# %%
# Find the difference between high, low and open prices for Shopify
shop_df["Diff_High_Low"] = shop_df["High"]  - shop_df["Low"]
shop_df["Diff_High_Open"] = shop_df["High"]  - shop_df["Open"]
shop_df["Diff_Open_Close"] = shop_df["Open"]  - shop_df["Close"]
shop_df["Diff_Open_Low"] = shop_df["Open"]  - shop_df["Low"]

# %%
# Create a Scatter plot between Date and Stock Opening Price - Tesla stock
tesla_df['Date'] = pd.to_datetime(tesla_df.Date,format='%Y-%m-%d')
tesla_df.index = tesla_df['Date']


fig = plt.figure(figsize=(25,10))

# Scatter plot and labels
plt.plot(tesla_df['Open'], color = 'red')
plt.plot(tesla_df['High'], color = 'blue')


# title and labels
plt.title('Tesla Stock - Price History', fontsize=20)
plt.xlabel('Date', fontsize=20)
plt.ylabel('Price($)', fontsize=20)


# Rotate xticks to show vertical
plt.xticks(rotation=90, fontsize=20)
plt.yticks(fontsize=20)


# Adjust scales, Legend
classes = ['Opening Price', 'Closing Price']
plt.yticks(np.arange(10, 550, 20))
plt.legend(classes, fontsize=20)


# Show map
plt.show()

# %%
# Create a Scatter plot between Date and Stock Opening Price - Amazon stock
amazon_df['Date'] = pd.to_datetime(amazon_df.Date,format='%Y-%m-%d')
amazon_df.index = amazon_df['Date']


fig = plt.figure(figsize=(25,10))

# Scatter plot and labels
plt.plot(amazon_df['Open'], color = 'red')
plt.plot(amazon_df['High'], color = 'blue')


# title and labels
plt.title('Amazon Stock - Price History', fontsize=20)
plt.xlabel('Date', fontsize=20)
plt.ylabel('Price($)', fontsize=20)


# Rotate xticks to show vertical
plt.xticks(rotation=90, fontsize=20)
plt.yticks(fontsize=20)

# Adjust scales, Legend
plt.yticks(np.arange(100, 4000, 150))
classes = ['Opening Price', 'Closing Price']
plt.legend(classes, fontsize=20)


# Show map
plt.show()

# %%
# Create a Scatter plot between Date and Stock Opening Price - Shopify stock
shop_df['Date'] = pd.to_datetime(shop_df.Date,format='%Y-%m-%d')
shop_df.index = shop_df['Date']


fig = plt.figure(figsize=(25,10))

# Scatter plot and labels
plt.plot(shop_df['Open'], color = 'red')
plt.plot(shop_df['High'], color = 'blue')


# title and labels
plt.title('Shop Stock - Price History', fontsize=20)
plt.xlabel('Date', fontsize=20)
plt.ylabel('Price($)', fontsize=20)


# Rotate xticks to show vertical
plt.xticks(rotation=90, fontsize=20)
plt.yticks(fontsize=20)

# Adjust scales
plt.yticks(np.arange(10,1200,50))
classes = ['Opening Price', 'Closing Price']
plt.legend(classes, fontsize=20)


# Show map
plt.show()

# %%
# Make a plot of the daily price fluctuations -  Tesla Stock
plt.figure(figsize=(15,10))
plt.plot(tesla_df["Diff_Open_Close"])

# Make a plot
plt.title('Tesla Stock - Daily Price Fluctuations Overtime ', fontsize=20)
plt.ylabel('Opening and Closing Price Difference($)', fontsize=20)
plt.xlabel('Date', fontsize=20)
# Out:
# Text(0.5, 0, 'Date')

# %%
# Make a plot of the daily price fluctuations -  Amazon Stock
plt.figure(figsize=(15,10))
plt.plot(amazon_df["Diff_Open_Close"])

# Make a plot
plt.title('Amazon Stock - Daily Price Fluctuations  ', fontsize=20)
plt.ylabel('Opening and Closing Price Difference($)', fontsize=20)
plt.xlabel('Date', fontsize=20)
# Out:
# Text(0.5, 0, 'Date')

# %%
# Make a plot of the daily opening and Closing price of Shopify Stock
plt.figure(figsize=(15,10))
plt.plot(shop_df["Diff_Open_Close"])

# Make a plot
plt.title('Shop Stock - Daily Price Fluctuations  ', fontsize=20)
plt.ylabel('Opening and Closing Price Difference($)', fontsize=20)
plt.xlabel('Date', fontsize=20)
# Out:
# Text(0.5, 0, 'Date')

# %%
# Make a plot of the open and Peak price of Shopify Stock
plt.figure(figsize=(15,10))
plt.plot(shop_df["Diff_High_Open"])

# Make a plot
plt.title('Shopify Stock - The Peak Price and Opening Price Difference per day', fontsize=20)
plt.ylabel('Difference($)', fontsize=20)
plt.xlabel('Date', fontsize=20)
# Out:
# Text(0.5, 0, 'Date')

# %%
# Make a plot of the open and Peak price of Tesla Stock
plt.figure(figsize=(15,10))
plt.plot(tesla_df["Diff_High_Open"])

# Make a plot
plt.title('Tesla Stock - The Peak Price and Opening Price Difference per day', fontsize=20)
plt.ylabel('Difference($)', fontsize=20)
plt.xlabel('Date', fontsize=20)
# Out:
# Text(0.5, 0, 'Date')

# %%
# Make a plot of the open and Peak price of Amazon Stock
plt.figure(figsize=(15,10))
plt.plot(amazon_df["Diff_High_Open"])

# Make a plot
plt.title('Amazon Stock - The Peak Price and Opening Price Difference per day', fontsize=20)
plt.ylabel('Difference($)', fontsize=20)
plt.xlabel('Date', fontsize=20)
# Out:
# Text(0.5, 0, 'Date')

# %%
# # Create a Scatter plot between Opening Price Vs. Opening and Peak Price Difference - Shopify stock
fig = plt.figure(figsize=(25,10))

colors1=np.random.rand(shop_df["Open"].shape[0])

# Scatter plot and labels
plt.scatter(shop_df["Open"],shop_df["Diff_High_Open"],c=colors1, linewidths=5)

plt.title('Shopify Opening Price Vs. Difference between Opening and Peak price', fontsize=20)
plt.xlabel('Opening Price', fontsize=20)
plt.ylabel('Price Difference (Peak - Opening) ($)', fontsize=20)


# Rotate xticks to show vertical
plt.xticks(rotation=90, fontsize=15)
plt.yticks(fontsize=15)

# Adjust scales
plt.yticks(np.arange(0, 100, 5))
plt.xticks(np.arange(10, 1200, 50))


# Show map
plt.show()

# %%
# Draw histogram for daily high price for tesla stock
tesla_df.hist(column='Diff_High_Open', bins=60, grid=False, figsize=(15,10), color='#306998', zorder=2, rwidth=0.9)

# Set title
plt.title("Tesla stock (TSLA) Opening Price and Peak Price Difference Distribution")

# Set x-axis label
plt.xlabel("Difference($)", labelpad=20, weight='bold', size=15)

# Set y-axis label
plt.ylabel("Number of Days", labelpad=80, weight='bold', size=15)


# Adjust scales
plt.yticks(np.arange(0, 2000, 100))
plt.xticks(np.arange(0, 40, 1),rotation=90)
# Out:
# ([<matplotlib.axis.XTick at 0x1c3299a2cc8>,
# ...
#  <a list of 40 Text major ticklabel objects>)

# %%
# Draw histogram for daily high price for Amazon stock
amazon_df.hist(column='Diff_High_Open', bins=60, grid=False, figsize=(15,10), color='#306998', zorder=2, rwidth=0.9)

# Set title
plt.title("Amazon stock (AMZN) Opening Price and Peak Price Difference Distribution")

# Set x-axis label
plt.xlabel("Difference($)", labelpad=20, weight='bold', size=15)

# Set y-axis label
plt.ylabel("Number of Days", labelpad=80, weight='bold', size=15)


# Adjust scales
plt.yticks(np.arange(0, 1000, 100))
plt.xticks(np.arange(0, 150, 5),rotation=90)
# Out:
# ([<matplotlib.axis.XTick at 0x1c3275aebc8>,
# ...
#  <a list of 30 Text major ticklabel objects>)

# %%
# Draw histogram for daily high price for Shopify stock
shop_df.hist(column='Diff_High_Open', bins=60, grid=False, figsize=(15,10), color='#306998', zorder=2, rwidth=0.9)

# Set title
plt.title("Shopify stock (SHOP) Opening Price and Peak Price Difference Distribution")

# Set x-axis label
plt.xlabel("Difference($)", labelpad=20, weight='bold', size=15)

# Set y-axis label
plt.ylabel("Number of Days", labelpad=80, weight='bold', size=15)


# Adjust scales
plt.yticks(np.arange(0, 700, 100))
plt.xticks(np.arange(0, 80, 2),rotation=90)
# Out:
# ([<matplotlib.axis.XTick at 0x1c329c2ac48>,
# ...
#  <a list of 40 Text major ticklabel objects>)

# %%
x_loss = tesla_df[tesla_df['Diff_Open_Close'] < 0]['Open']

# %%
# Draw a scatter plot between loss and profit - Shopfy stock

fig = plt.figure(figsize=(40,20))

x_loss = shop_df[shop_df['Diff_Open_Close'] < 0]['Open']
y_loss = shop_df[shop_df['Diff_Open_Close'] < 0]['Diff_Open_Close']


x_profit =  shop_df[shop_df['Diff_Open_Close'] > 0]['Open']
y_profit = shop_df[shop_df['Diff_Open_Close'] > 0]['Diff_Open_Close']


plt.scatter(x_loss,y_loss,marker='+',color='red')
plt.scatter(x_profit,y_profit,marker='*',color='green')

plt.show()

# %%
# reset index
shop_df= shop_df.reset_index(drop=True)

# %%
# Create a linear regression model between open price and the difference of open and peak price
# Prepare test and training datasets for leniar regression
from sklearn import linear_model
from sklearn.model_selection import train_test_split


X = np.array(shop_df[['Open']])
Y = np.array(shop_df[['Diff_High_Open']])

# 80% Training and 20% testing
x_train, x_test, y_train, y_test = train_test_split(X, Y, train_size=0.8)

# Train the model
regr = linear_model.LinearRegression()
regr.fit(x_train, y_train)

coeff = regr.coef_
intercpt = regr.intercept_

# print values
print("coefficient", coeff)
print("Intercept", intercpt)
# Out:
# coefficient [[0.0213037]]
# Intercept [0.17154857]

# %%
# Predict the outcome
y_pred = regr.predict(x_test)

# %%
# Compare the actual values with the predicted values
shop_regr = pd.DataFrame({'Actual': y_test.flatten(), 'Predicted': y_pred.flatten()})
shop_regr
# Out:
#         Actual  Predicted
# 0    14.940002   5.409701
# 1     3.300003   2.338134
# 2     0.750000   0.763578
# 3     4.929992   3.201147
# 4     0.360001   0.804694
# ..         ...        ...
# 247   6.786011  10.184286
# 248   0.519998   0.689015
# 249   1.400002   2.107628
# 250   1.899994   3.145545
# 251   3.559998   3.174092
#
# [252 rows x 2 columns]

# %%
shop_regr_df= shop_regr.head(50)
shop_regr_df.plot(kind='bar',figsize=(16,10))
plt.plot(which='major', linestyle='-', linewidth='0.8', color='green')
plt.plot(which='minor', linestyle=':', linewidth='0.8', color='black')
plt.title("Predicted profit vs. Actual profit When stocks are bought at any opening price")
plt.show()

# %%
# Find Mean values
from sklearn import metrics
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))  
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 3.4144433417753133
# Mean Squared Error: 46.6180215383477
# Root Mean Squared Error: 6.827739123483534

# %%
print(shop_df['Diff_High_Open'].mean())
# Out:
# 5.225630539316918

# %%
# Create plot for the test data
fig = plt.figure(figsize=(35,10))

plt.scatter(x_test, y_test,  color='blue')
plt.plot(x_test, y_pred, color='red', linewidth=3)


# Set title
plt.title("Predicted vs. Test Values")


plt.show()

# %%
# Create a dataframe where Opening price is more than 500
shop_df_500 = shop_df[shop_df['Open'] > 500]

# %%
# Create a linear regression model between open price and the difference of open and peak price
# Prepare test and training datasets for leniar regression
from sklearn import linear_model
from sklearn.model_selection import train_test_split


X = np.array(shop_df_500[['Open']])
Y = np.array(shop_df_500[['Diff_High_Open']])

# 80% Training and 20% testing
x_train, x_test, y_train, y_test = train_test_split(X, Y, train_size=0.8)

# Train the model
regr = linear_model.LinearRegression()
regr.fit(x_train, y_train)

coeff = regr.coef_
intercpt = regr.intercept_

# print values
print("coefficient", coeff)
print("Intercept", intercpt)
# Out:
# coefficient [[0.00262818]]
# Intercept [16.63610827]

# %%
# Predict the outcome
y_pred = regr.predict(x_test)

# %%
# Compare the actual values with the predicted values
shop_regr_500 = pd.DataFrame({'Actual': y_test.flatten(), 'Predicted': y_pred.flatten()})
shop_regr_500
# Out:
#        Actual  Predicted
# 0   29.900025  19.358879
# 1   17.450012  19.026571
# 2   59.950012  18.173595
# 3   18.768921  19.419827
# 4    5.700074  19.477357
# 5   19.869995  18.645170
# 6   14.750000  18.988647
# 7    2.000000  18.849038
# 8   13.895996  19.516570
# 9   24.989991  18.131281
# 10  41.539978  19.053274
# 11  28.000000  19.185445
# 12  71.910034  19.461404
# 13  26.010010  19.471891
# 14   3.329956  19.556019
# 15  18.010010  18.717261
# 16  16.510009  19.107519
# 17  14.880005  18.039558
# 18   0.729980  18.659809
# 19  20.489990  18.618546
# 20  13.169983  19.177088
# 21   6.000000  19.195958
# 22  15.840027  19.171595
# 23  33.090027  19.056428
# 24   4.700012  19.270335
# 25   5.000000  19.185445
# 26  24.750000  19.416725
# 27  14.494019  18.772821
# 28  45.539978  18.494128
# 29  33.500000  19.318168

# %%
# Predicted vs. Actual
shop_regr_500= shop_regr_500.head(50)
shop_regr_500.plot(kind='bar',figsize=(16,10))
plt.plot(which='major', linestyle='-', linewidth='0.8', color='green')
plt.plot(which='minor', linestyle=':', linewidth='0.8', color='black')
plt.title("Shop stock - Predicted profit vs. Actual profit When stocks are bought at Opening price > $500")
plt.show()

# %%
# Find Mean values
from sklearn import metrics
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))  
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 13.718953064753867
# Mean Squared Error: 259.8640251953947
# Root Mean Squared Error: 16.12029854547969

# %%
shop_df_500.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count   147.000000   147.000000   147.000000   147.000000   147.000000
# mean    889.293605   908.772059   864.709361   887.851021   887.851021
# std     171.030893   171.828869   167.222625   168.458896   168.458896
# min     501.480011   503.000000   467.519989   476.940002   476.940002
# 25%     754.864990   768.990021   733.000000   751.675018   751.675018
# 50%     940.349976   956.859985   910.700012   929.809998   929.809998
# 75%    1033.494995  1053.125000  1003.002502  1025.204956  1025.204956
# max    1142.000000  1146.910034  1086.364990  1134.319946  1134.319946
#
#              Volume  Diff_High_Low  Diff_High_Open  Diff_Open_Close  \
# count  1.470000e+02     147.000000      147.000000       147.000000
# mean   2.748404e+06      44.062699       19.478454         1.442584
# std    1.592513e+06      20.832973       16.445138        29.266790
# ...

# %%
# Create a dataframe where Opening price is more than 500
shop_df_900 = shop_df[shop_df['Open'] > 900]

# %%
# Create a linear regression model between open price and the difference of open and peak price
# Prepare test and training datasets for leniar regression
from sklearn import linear_model
from sklearn.model_selection import train_test_split


X = np.array(shop_df_900[['Open']])
Y = np.array(shop_df_900[['Diff_High_Open']])

# 80% Training and 20% testing
x_train, x_test, y_train, y_test = train_test_split(X, Y, train_size=0.8)

# Train the model
regr = linear_model.LinearRegression()
regr.fit(x_train, y_train)

coeff = regr.coef_
intercpt = regr.intercept_

# print values
print("coefficient", coeff)
print("Intercept", intercpt)
# Out:
# coefficient [[-0.05657811]]
# Intercept [78.53646605]

# %%
# Predict the outcome
y_pred = regr.predict(x_test)

# %%
# Compare the actual values with the predicted values
shop_regr_900 = pd.DataFrame({'Actual': y_test.flatten(), 'Predicted': y_pred.flatten()})
shop_regr_900
# Out:
#        Actual  Predicted
# 0    5.310059  19.825932
# 1    1.000000  25.466200
# 2    6.409912  16.679617
# 3    9.010010  26.824641
# 4    1.980103  18.983483
# 5    5.000000  23.655701
# 6   11.044983  26.710918
# 7    8.900025  18.666081
# 8   14.020020  18.849959
# 9   19.419922  17.953757
# 10  57.250000  20.147858
# 11   8.769959  25.794352
# 12  82.809998  25.975403
# 13   5.700074  17.371573
# 14  10.810974  25.239321
# 15  20.640015  22.014935
# 16  10.417969  18.111046
# 17   4.700012  21.828228

# %%
# Predicted vs. Actual
shop_regr_900= shop_regr_900.head(100)
shop_regr_900.plot(kind='bar',figsize=(16,10))
plt.plot(which='major', linestyle='-', linewidth='0.8', color='green')
plt.plot(which='minor', linestyle=':', linewidth='0.8', color='black')
plt.title("Shop stock - Predicted profit vs. Actual profit When stocks are bought at Opening price > $900")
plt.show()

# %%
# Find Mean values
from sklearn import metrics
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))  
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 16.5394875221212
# Mean Squared Error: 435.0544271622096
# Root Mean Squared Error: 20.857958365147095

# %%
# Mean value of the actual and predicted when stock > $900
shop_regr_900.mean()
# Out:
# Actual       15.733002
# Predicted    21.672167
# dtype: float64

# %%
# Mean value of the actual and predicted when stock > $500
shop_regr_500.mean()
# Out:
# Actual       16.228801
# Predicted    20.366681
# dtype: float64

# %%
# Shopify stock prediction
# Expected to get a profit of minimum $15 when price of the stock is > 900 and the stock is bought at the opening price of the stock
# Expected to get a profit of minimum $16 when price of the stock is > 500 and the stock is bought at the opening price of the stock

# %%
# Develop linear regression for Amazon stock
# reset index
amazon_df= amazon_df.reset_index(drop=True)

# %%
# Create a linear regression model between open price and the difference of open and peak price
# Prepare test and training datasets for leniar regression
from sklearn import linear_model
from sklearn.model_selection import train_test_split


X = np.array(amazon_df[['Open']])
Y = np.array(amazon_df[['Diff_High_Open']])

# 80% Training and 20% testing
x_train, x_test, y_train, y_test = train_test_split(X, Y, train_size=0.8)

# Train the model
regr = linear_model.LinearRegression()
regr.fit(x_train, y_train)

coeff = regr.coef_
intercpt = regr.intercept_

# print values
print("coefficient", coeff)
print("Intercept", intercpt)
# Out:
# coefficient [[0.01171257]]
# Intercept [-1.3147201]

# %%
# Predict the outcome for amazon stock
y_pred = regr.predict(x_test)
# Compare the actual values with the predicted values
amazon_regr = pd.DataFrame({'Actual': y_test.flatten(), 'Predicted': y_pred.flatten()})
amazon_regr
amazon_regr_df= amazon_regr.head(50)
amazon_regr_df.plot(kind='bar',figsize=(16,10))
plt.plot(which='major', linestyle='-', linewidth='0.8', color='green')
plt.plot(which='minor', linestyle=':', linewidth='0.8', color='black')
plt.title("Predicted profit vs. Actual profit When stocks are bought at any opening price")
plt.show()

# %%
# Create a dataframe where Opening price is more than 3000
amazon_df_3000 = amazon_df[amazon_df['Open'] > 3000]
# Create a linear regression model between open price and the difference of open and peak price
# Prepare test and training datasets for leniar regression
from sklearn import linear_model
from sklearn.model_selection import train_test_split


X = np.array(amazon_df_3000[['Open']])
Y = np.array(amazon_df_3000[['Diff_High_Open']])

# 80% Training and 20% testing
x_train, x_test, y_train, y_test = train_test_split(X, Y, train_size=0.8)

# Train the model
regr = linear_model.LinearRegression()
regr.fit(x_train, y_train)

coeff = regr.coef_
intercpt = regr.intercept_

# print values
print("coefficient", coeff)
print("Intercept", intercpt)
# Predict the outcome
y_pred = regr.predict(x_test)
# Compare the actual values with the predicted values
amazon_regr_3000 = pd.DataFrame({'Actual': y_test.flatten(), 'Predicted': y_pred.flatten()})
amazon_regr_3000

# Predicted vs. Actual
amazon_regr_3000= amazon_regr_3000.head(100)
amazon_regr_3000.plot(kind='bar',figsize=(16,10))
plt.plot(which='major', linestyle='-', linewidth='0.8', color='green')
plt.plot(which='minor', linestyle=':', linewidth='0.8', color='black')
plt.title("amazon stock - Predicted profit vs. Actual profit When stocks are bought at Opening price > $3000")
plt.show()

# Find Mean values
from sklearn import metrics
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))  
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))  
#print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# coefficient [[-0.01212471]]
# Intercept [77.96292066]
# Mean Absolute Error: 37.24215554906127
# Mean Squared Error: 2583.5547416055447

# %%
# Mean value of the actual and predicted when stock > $900
amazon_regr_3000.mean()
# Out:
# Actual       34.328094
# Predicted    44.036016
# dtype: float64

# %%
# Create a linear regression Model for Tesla Stock
# reset index
tesla_df= tesla_df.reset_index(drop=True)

# %%
# Create a linear regression model between open price and the difference of open and peak price
# Prepare test and training datasets for leniar regression
from sklearn import linear_model
from sklearn.model_selection import train_test_split


X = np.array(tesla_df[['Open']])
Y = np.array(tesla_df[['Diff_High_Open']])

# 80% Training and 20% testing
x_train, x_test, y_train, y_test = train_test_split(X, Y, train_size=0.8)

# Train the model
regr = linear_model.LinearRegression()
regr.fit(x_train, y_train)

coeff = regr.coef_
intercpt = regr.intercept_

# print values
print("coefficient", coeff)
print("Intercept", intercpt)
# Out:
# coefficient [[0.02781605]]
# Intercept [-0.31395368]

# %%
# Predict the outcome for tesla stock
y_pred = regr.predict(x_test)
# Compare the actual values with the predicted values
tesla_regr = pd.DataFrame({'Actual': y_test.flatten(), 'Predicted': y_pred.flatten()})
tesla_regr
tesla_regr_df= tesla_regr.head(50)
tesla_regr_df.plot(kind='bar',figsize=(16,10))
plt.plot(which='major', linestyle='-', linewidth='0.8', color='green')
plt.plot(which='minor', linestyle=':', linewidth='0.8', color='black')
plt.title("Predicted profit vs. Actual profit When stocks are bought at any opening price")
plt.show()

# %%
# Create a dataframe where Opening price is more than 400
tesla_df_400 = tesla_df[tesla_df['Open'] > 400]
# Create a linear regression model between open price and the difference of open and peak price
# Prepare test and training datasets for leniar regression
from sklearn import linear_model
from sklearn.model_selection import train_test_split


X = np.array(tesla_df_400[['Open']])
Y = np.array(tesla_df_400[['Diff_High_Open']])

# 80% Training and 20% testing
x_train, x_test, y_train, y_test = train_test_split(X, Y, train_size=0.8)

# Train the model
regr = linear_model.LinearRegression()
regr.fit(x_train, y_train)

coeff = regr.coef_
intercpt = regr.intercept_

# print values
print("coefficient", coeff)
print("Intercept", intercpt)
# Predict the outcome
y_pred = regr.predict(x_test)
# Compare the actual values with the predicted values
tesla_regr_400 = pd.DataFrame({'Actual': y_test.flatten(), 'Predicted': y_pred.flatten()})
tesla_regr_400

# Predicted vs. Actual
tesla_regr_400= tesla_regr_400.head(100)
tesla_regr_400.plot(kind='bar',figsize=(16,10))
plt.plot(which='major', linestyle='-', linewidth='0.8', color='green')
plt.plot(which='minor', linestyle=':', linewidth='0.8', color='black')
plt.title("tesla stock - Predicted profit vs. Actual profit When stocks are bought at Opening price > $400")
plt.show()

# Find Mean values
from sklearn import metrics
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))  
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# coefficient [[-0.14843377]]
# Intercept [74.62347835]
# Mean Absolute Error: 7.196816244099214
# Mean Squared Error: 70.03384888726562
# Root Mean Squared Error: 8.368622878781528

# %%
# Mean value of the actual and predicted when stock > $900
tesla_regr_400.mean()
# Out:
# Actual        8.450443
# Predicted    10.931305
# dtype: float64
